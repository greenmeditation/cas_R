# %% [markdown]
# ## Time Series Notebook
#
# start : 2020, 04

# %%
from numpy import *
from scipy import *
from pylab import *
from scipy import ndimage
import scipy.io as sio

# %%
aA1=array([1342,1442,1252,1343,
           1425,1362,1456,1272,
	     1243,1359,1412,1253,
	     1201,1478,1322,1406,
	     1254,1289,1497,1208]);

# %%
aA2=array([ 1242,1242,1452,1543,
	     1125,1262,1456,1572,
	     1143,1259,1462,1553,
	     1121,1258,1472,1546,
	     1254,1249,1477,1548   ]);

# %%
aA3=array([ 1142,1142,1252,1343,
	     1225,1562,1356,1572,
	     1343,1459,1412,1453,
	     1401,1478,1322,1606,
	     1554,1589,1597,1408 ])

# %%
aA4=array([1142,1242,1452,1543,
	     1225,1362,1556,1672,
	     1343,1459,1662,1753,
	     1421,1558,1722,1846,
	     1554,1649,1877,1948  ])

# %%
aA5=array([1142,1242,1452,1543,
	     1225,1362,1556,1672,
	     1343,1459,1662,1753,
	     1231,1358,1572,1646,
	     1154,1249,1477,1548 ])

# %%
aA6=array([1342,1442,1252,1343,
	     1425,1362,1456,1272,
	     1243,1359,1812,1653,
	     1601,1878,1762,1806,
	     1654,1689,1897,1608])

# %%
timeseries_data={'aA1':aA1, 'aA2':aA2, 'aA3':aA3,'aA4':aA4,'aA5':aA5,'aA6':aA6};
sio.savemat('c:/tmp/timeseries_data.mat',timeseries_data)
